# %%
class Income():

    def __init__(self, year, month, salary, bonus):
        self.__year = year
        self.__month = month
        self.__salary = salary
        self.__bonus = bonus
        self.__income = {self.__year: {"January": {"salary": 0.0, "bonus": 0.0, "total": 0.0}, 
                                       "February": {"salary": 0.0, "bonus": 0.0, "total": 0.0}, 
                                       "March": {"salary": 0.0, "bonus": 0.0, "total": 0.0}, 
                                       "April": {"salary": 0.0, "bonus": 0.0, "total": 0.0}, 
                                       "May": {"salary": 0.0, "bonus": 0.0, "total": 0.0}, 
                                       "June": {"salary": 0.0, "bonus": 0.0, "total": 0.0}, 
                                       "July": {"salary": 0.0, "bonus": 0.0, "total": 0.0}, 
                                       "August": {"salary": 0.0, "bonus": 0.0, "total": 0.0}, 
                                       "September": {"salary": 0.0, "bonus": 0.0, "total": 0.0}, 
                                       "October": {"salary": 0.0, "bonus": 0.0, "total": 0.0}, 
                                       "November": {"salary": 0.0, "bonus": 0.0, "total": 0.0}, 
                                       "December": {"salary": 0.0, "bonus": 0.0, "total": 0.0},
                                       "Total": {"salary": 0.0, "bonus": 0.0, "total": 0.0}}}
        if salary != None:
            self.__income[year][month]["salary"] = salary
        if bonus != None:
            self.__income[year][month]["bonus"] = bonus
        if salary != None and bonus != None:
            self.__income[year][month]["total"] = self.__salary + self.__bonus
        if salary != None:
            self.__income[year]["Total"]["salary"] = self.__salary 
        if bonus != None:
            self.__income[year]["Total"]["bonus"] = self.__bonus
        if salary != None and bonus != None:
            self.__income[year]["Total"]["total"] = self.__salary + self.__bonus

    def __str__(self):
        display = ("************************************************************"
            + "\n {:49s}".format("                INCOME FOR YEAR - " + str(self.__year)) 
            + "\n {a:<15s} {b:<15s} {c:<15s} {d:<15s}".format(a="MONTH", b="SALARY", c="BONUS", d="TOTAL") 
            + "\n" + "************************************************************\n")
        for val in self.__income[self.__year].items():
            display += "{a:<15s} {b:<15.2f} {c:<15.2f} {d:<15.2f}".format(a=val[0], b=val[1]["salary"], c=val[1]["bonus"], d=val[1]["total"]) + "\n" 
        display += "************************************************************\n"
        return display

    def monthly_income(self):
        return "Total income in " + str(self.__month) + ": ${}".format(self.__salary + self.__bonus)
    
    def add_income(self, year, month, salary = 0, bonus = 0):
        self.__income[year][month]["salary"] += salary
        self.__income[year][month]["bonus"] += bonus
        self.__income[year][month]["total"] += (salary + bonus)
        self.__income[year]["Total"]["salary"] += salary
        self.__income[year]["Total"]["bonus"] += bonus
        self.__income[year]["Total"]["total"] += (salary + bonus)
        return "Income has been added"
    
    def update_salary(self, year, month, salary):
        temp = self.__income[year][month]["salary"]
        self.__income[year][month]["salary"] = salary
        self.__income[year][month]["total"] += (salary - temp)
        self.__income[year]["Total"]["salary"] += (salary - temp)
        self.__income[year]["Total"]["total"] += (salary - temp)
        return "Salary has been updated"
    
    def update_bonus(self, year, month, bonus):
        temp = self.__income[year][month]["bonus"]
        self.__income[year][month]["bonus"] = bonus
        self.__income[year][month]["total"] += (bonus - temp)
        self.__income[year]["Total"]["bonus"] += (bonus - temp)
        self.__income[year]["Total"]["total"] += (bonus - temp)
        return "Bonus has been updated"

class Expense():
    
    def __init__(self, year, month, rent, grocery, auto, medical, other):
        self.__year = year
        self.__month = month
        self.__rent = rent
        self.__grocery = grocery
        self.__auto = auto
        self.__medical = medical 
        self.__other = other
        self.__expenses = {self.__year: {"January": {"rent": 0.0, "grocery": 0.0, "auto": 0.0, "medical": 0.0, "other": 0.0, "total": 0.0}, 
                                       "February": {"rent": 0.0, "grocery": 0.0, "auto": 0.0, "medical": 0.0, "other": 0.0, "total": 0.0}, 
                                       "March": {"rent": 0.0, "grocery": 0.0, "auto": 0.0, "medical": 0.0, "other": 0.0, "total": 0.0}, 
                                       "April": {"rent": 0.0, "grocery": 0.0, "auto": 0.0, "medical": 0.0, "other": 0.0, "total": 0.0}, 
                                       "May": {"rent": 0.0, "grocery": 0.0, "auto": 0.0, "medical": 0.0, "other": 0.0, "total": 0.0}, 
                                       "June": {"rent": 0.0, "grocery": 0.0, "auto": 0.0, "medical": 0.0, "other": 0.0, "total": 0.0}, 
                                       "July": {"rent": 0.0, "grocery": 0.0, "auto": 0.0, "medical": 0.0, "other": 0.0, "total": 0.0}, 
                                       "August": {"rent": 0.0, "grocery": 0.0, "auto": 0.0, "medical": 0.0, "other": 0.0, "total": 0.0}, 
                                       "September": {"rent": 0.0, "grocery": 0.0, "auto": 0.0, "medical": 0.0, "other": 0.0, "total": 0.0}, 
                                       "October": {"rent": 0.0, "grocery": 0.0, "auto": 0.0, "medical": 0.0, "other": 0.0, "total": 0.0}, 
                                       "November": {"rent": 0.0, "grocery": 0.0, "auto": 0.0, "medical": 0.0, "other": 0.0, "total": 0.0}, 
                                       "December": {"rent": 0.0, "grocery": 0.0, "auto": 0.0, "medical": 0.0, "other": 0.0, "total": 0.0}, 
                                       "Total": {"rent": 0.0, "grocery": 0.0, "auto": 0.0, "medical": 0.0, "other": 0.0, "total": 0.0}}}
        if rent != None:
            self.__expenses[year][month]["rent"] = rent
        if grocery != None:
            self.__expenses[year][month]["grocery"] = grocery
        if auto != None:
            self.__expenses[year][month]["auto"] = auto
        if medical != None:
            self.__expenses[year][month]["medical"] = medical
        if other != None:
            self.__expenses[year][month]["other"] = other 
        if rent != None and grocery != None and auto != None and medical != None and other != None:
            self.__expenses[year][month]["total"] = self.__rent + self.__grocery + self.__auto + self.__medical + self.__other
            self.__expenses[year]["Total"]["total"] = self.__rent + self.__grocery + self.__auto + self.__medical + self.__other

    def __str__(self):
        display = ("*************************************************************************************************************"
        + "\n {:100s}".format("                                        EXPENSES FOR YEAR - " + str(self.__year))
        + "\n {a:<15s} {b:<15s} {c:<15s} {d:<15s} {e:<15s} {f:<15s} {g:<15s}".format(a="MONTH", b="RENT", c="GROCERY", d="AUTO", e="MEDICAL", f="OTHER", g="TOTAL") 
        + "\n" + "*************************************************************************************************************\n")
        for val in self.__expenses[self.__year].items():
            display += "{a:<15s} {b:<15.2f} {c:<15.2f} {d:<15.2f} {e:<15.2f} {f:<15.2f} {g:<15.2f}".format(a=val[0], b=val[1]["rent"], c=val[1]["grocery"], d=val[1]["auto"], e=val[1]["medical"], f=val[1]["other"], g=val[1]["total"]) + "\n" 
        display += "*************************************************************************************************************\n"
        return display

    def monthly_expenses(self):
        return "Total expenses in " + self.__month + ": ${}".format(self.__rent + self.__grocery + self.__auto + self.__medical + self.__other)
    
    def add_expenses(self, year, month, rent, grocery, auto, medical, other):
        self.__expenses[year][month]["rent"] += rent
        self.__expenses[year][month]["grocery"] += grocery
        self.__expenses[year][month]["auto"] += auto
        self.__expenses[year][month]["medical"] += medical
        self.__expenses[year][month]["other"] += other
        self.__expenses[year][month]["total"] += (rent + grocery + auto + medical + other)
        self.__expenses[year]["Total"]["rent"] += rent
        self.__expenses[year]["Total"]["grocery"] += grocery
        self.__expenses[year]["Total"]["auto"] += auto
        self.__expenses[year]["Total"]["medical"] += medical
        self.__expenses[year]["Total"]["other"] += other
        self.__expenses[year]["Total"]["total"] += (rent + grocery + auto + medical + other)
        return "Expenses has been added"
    
    def update_rent(self, year, month, rent):
        temp = self.__expenses[year][month]["rent"] 
        self.__expenses[year][month]["rent"] = rent
        self.__expenses[year][month]["total"] += (rent - temp)
        self.__expenses[year]["Total"]["rent"] += (rent - temp)
        self.__expenses[year]["Total"]["total"] += (rent - temp)
        return "Rent has been updated"

    def update_grocery(self, year, month, grocery):
        temp = self.__expenses[year][month]["grocery"] 
        self.__expenses[year][month]["grocery"] = grocery
        self.__expenses[year][month]["total"] += (grocery - temp)
        self.__expenses[year]["Total"]["grocery"] += (grocery - temp)
        self.__expenses[year]["Total"]["total"] += (grocery - temp)
        return "Grocery has been updated"
    
    def update_auto_expenses(self, year, month, auto):
        temp = self.__expenses[year][month]["auto"] 
        self.__expenses[year][month]["auto"] = auto
        self.__expenses[year][month]["total"] += (auto - temp)
        self.__expenses[year]["Total"]["auto"] += (auto - temp)
        self.__expenses[year]["Total"]["total"] += (auto - temp)
        return "Auto expenses have been updated"
    
    def update_medical_expenses(self, year, month, medical):
        temp = self.__expenses[year][month]["medical"] 
        self.__expenses[year][month]["medical"] = medical
        self.__expenses[year][month]["total"] += (medical - temp)
        self.__expenses[year]["Total"]["medical"] += (medical - temp)
        self.__expenses[year]["Total"]["total"] += (medical - temp)
        return "Medical expenses have been updated"

    def update_other_expenses(self, year, month, other):
        temp = self.__expenses[year][month]["other"] 
        self.__expenses[year][month]["other"] = other
        self.__expenses[year][month]["total"] += (other - temp)
        self.__expenses[year]["Total"]["other"] += (other - temp)
        self.__expenses[year]["Total"]["total"] += (other - temp)
        return "Other expenses have been updated"

class Investment():

    def __init__(self, year, month, stocks, crypto, retirement_fund, realstate):
        self.__year = year
        self.__month = month
        self.__stocks = stocks 
        self.__crypto = crypto
        self.__retirement_fund = retirement_fund
        self.__realstate = realstate
        self.__investments = {self.__year: {"January": {"stocks": 0.0, "crypto": 0.0, "retirement_fund": 0.0, "realstate": 0.0, "total": 0.0}, 
                                       "February": {"stocks": 0.0, "crypto": 0.0, "retirement_fund": 0.0, "realstate": 0.0, "total": 0.0}, 
                                       "March": {"stocks": 0.0, "crypto": 0.0, "retirement_fund": 0.0, "realstate": 0.0, "total": 0.0}, 
                                       "April": {"stocks": 0.0, "crypto": 0.0, "retirement_fund": 0.0, "realstate": 0.0, "total": 0.0}, 
                                       "May": {"stocks": 0.0, "crypto": 0.0, "retirement_fund": 0.0, "realstate": 0.0, "total": 0.0}, 
                                       "June": {"stocks": 0.0, "crypto": 0.0, "retirement_fund": 0.0, "realstate": 0.0, "total": 0.0}, 
                                       "July": {"stocks": 0.0, "crypto": 0.0, "retirement_fund": 0.0, "realstate": 0.0, "total": 0.0}, 
                                       "August": {"stocks": 0.0, "crypto": 0.0, "retirement_fund": 0.0, "realstate": 0.0, "total": 0.0}, 
                                       "September": {"stocks": 0.0, "crypto": 0.0, "retirement_fund": 0.0, "realstate": 0.0, "total": 0.0}, 
                                       "October": {"stocks": 0.0, "crypto": 0.0, "retirement_fund": 0.0, "realstate": 0.0, "total": 0.0}, 
                                       "November": {"stocks": 0.0, "crypto": 0.0, "retirement_fund": 0.0, "realstate": 0.0, "total": 0.0}, 
                                       "December": {"stocks": 0.0, "crypto": 0.0, "retirement_fund": 0.0, "realstate": 0.0, "total": 0.0}, 
                                       "Total": {"stocks": 0.0, "crypto": 0.0, "retirement_fund": 0.0, "realstate": 0.0, "total": 0.0}}}
        if stocks != None:
            self.__investments[year][month]["stocks"] = stocks
        if crypto != None:
            self.__investments[year][month]["crypto"] = crypto
        if retirement_fund != None:
            self.__investments[year][month]["retirement_fund"] = retirement_fund
        if realstate != None:
            self.__investments[year][month]["realstate"] = realstate
        if stocks != None and crypto != None and retirement_fund != None and realstate != None:
            self.__investments[year][month]["total"] = (stocks + crypto + retirement_fund + realstate)
            self.__investments[year]["Total"]["stocks"] = stocks
            self.__investments[year]["Total"]["crypto"] = crypto
            self.__investments[year]["Total"]["retirement_fund"] = retirement_fund
            self.__investments[year]["Total"]["realstate"] = realstate
            self.__investments[year]["Total"]["total"] = (stocks + crypto + retirement_fund + realstate)

    
    def __str__(self):
        display = ("***********************************************************************************************"
        + "\n {:85s}".format("                               INVESTMENTS FOR YEAR - " + str(self.__year))
        + "\n{a:<15s} {b:<15s} {c:<15s} {d:<20s} {e:<15s} {f:<15s}".format(a="MONTH", b="STOCKS", c="CRYPTO", d="RETIREMENT FUND", e="REALSTATE", f="TOTAL") 
        + "\n" + "***********************************************************************************************\n")
        for val in self.__investments[self.__year].items():
            display += "{a:<15s} {b:<15.2f} {c:<15.2f} {d:<20.2f} {e:<15.2f} {f:<15.2f}".format(a=val[0], b=val[1]["stocks"], c=val[1]["crypto"], d=val[1]["retirement_fund"], e=val[1]["realstate"], f=val[1]["total"]) + "\n" 
        display += "***********************************************************************************************\n"
        return display

    def monthly_investment(self):
        return "Total investment in " + self.__month + ": ${}".format(self.__stocks + self.__crypto + self.__retirement_fund + self.__realstate)
    
    def add_investment(self, year, month, stocks, crypto, retirement_fund, realstate):
        self.__investments[year][month]["stocks"] += stocks
        self.__investments[year][month]["crypto"] += crypto
        self.__investments[year][month]["retirement_fund"] += retirement_fund
        self.__investments[year][month]["realstate"] += realstate
        self.__investments[year][month]["total"] += (stocks + crypto + retirement_fund + realstate) 
        self.__investments[year]["Total"]["stocks"] += stocks
        self.__investments[year]["Total"]["crypto"] += crypto
        self.__investments[year]["Total"]["retirement_fund"] += retirement_fund
        self.__investments[year]["Total"]["realstate"] += realstate
        self.__investments[year]["Total"]["total"] += (stocks + crypto + retirement_fund + realstate)
        return "Investments have been added"
    
    def update_stocks(self, year, month, stocks):
        temp = self.__investments[year][month]["stocks"] 
        self.__investments[year][month]["stocks"] = stocks
        self.__investments[year][month]["total"] += (stocks - temp)
        self.__investments[year]["Total"]["stocks"] += (stocks - temp)
        self.__investments[year]["Total"]["total"] += (stocks - temp)
        return "Stocks have been updated"
    
    def update_crypto(self, year, month, crypto):
        temp = self.__investments[year][month]["crypto"] 
        self.__investments[year][month]["crypto"] = crypto
        self.__investments[year][month]["total"] += (crypto - temp)
        self.__investments[year]["Total"]["crypto"] += (crypto - temp)
        self.__investments[year]["Total"]["total"] += (crypto - temp)
        return "Crypto investment has been updated"
    
    def update_retirement_fund(self, year, month, retirement_fund):
        temp = self.__investments[year][month]["retirement_fund"] 
        self.__investments[year][month]["retirement_fund"] = retirement_fund
        self.__investments[year][month]["total"] += (retirement_fund - temp)
        self.__investments[year]["Total"]["retirement_fund"] += (retirement_fund - temp)
        self.__investments[year]["Total"]["total"] += (retirement_fund - temp)
        return "Retirement_fund has been updated"
    
    def update_realstate(self, year, month, realstate):
        temp = self.__investments[year][month]["realstate"] 
        self.__investments[year][month]["realstate"] = realstate
        self.__investments[year][month]["total"] += (realstate - temp)
        self.__investments[year]["Total"]["realstate"] += (realstate - temp)
        self.__investments[year]["Total"]["total"] += (realstate - temp)
        return "Realstate investment has been updated"

class Budget(Income, Expense, Investment):

    __cash_flow = 0
    __net_worth = 0
    __liquid_assets = 0
    __net_debt = 0
    __net_investment = 0

    def __init__(self, year):
        self.__year = year
        Income.__init__(self, year = self.__year, month = None, salary = None, bonus = None)
        Expense.__init__(self, year = self.__year, month = None, rent = None, grocery = None, auto = None, medical = None, other = None)
        Investment.__init__(self, year = self.__year, month = None, stocks = None, crypto = None, retirement_fund = None, realstate = None)
    
    def __str__(self):
        display = ("************************************************************"
            + "\n {:49s}".format("                INCOME FOR YEAR - " + str(self.__year)) 
            + "\n {a:<15s} {b:<15s} {c:<15s} {d:<15s}".format(a="MONTH", b="SALARY", c="BONUS", d="TOTAL") 
            + "\n" + "************************************************************\n")
        for val in self.__income[self.__year].items():
            display += "{a:<15s} {b:<15.2f} {c:<15.2f} {d:<15.2f}".format(a=val[0], b=val[1]["salary"], c=val[1]["bonus"], d=val[1]["total"]) + "\n" 
        display += "************************************************************\n"
        display += ("*************************************************************************************************************"
        + "\n {:100s}".format("                                        EXPENSES FOR YEAR - " + str(self.__year))
        + "\n {a:<15s} {b:<15s} {c:<15s} {d:<15s} {e:<15s} {f:<15s} {g:<15s}".format(a="MONTH", b="RENT", c="GROCERY", d="AUTO", e="MEDICAL", f="OTHER", g="TOTAL") 
        + "\n" + "*************************************************************************************************************\n")
        for val in self.__expenses[self.__year].items():
            display += "{a:<15s} {b:<15.2f} {c:<15.2f} {d:<15.2f} {e:<15.2f} {f:<15.2f} {g:<15.2f}".format(a=val[0], b=val[1]["rent"], c=val[1]["grocery"], d=val[1]["auto"], e=val[1]["medical"], f=val[1]["other"], g=val[1]["total"]) + "\n" 
        display += "*************************************************************************************************************\n"
        display += ("***********************************************************************************************"
        + "\n {:85s}".format("                               INVESTMENTS FOR YEAR - " + str(self.__year))
        + "\n{a:<15s} {b:<15s} {c:<15s} {d:<20s} {e:<15s} {f:<15s}".format(a="MONTH", b="STOCKS", c="CRYPTO", d="RETIREMENT FUND", e="REALSTATE", f="TOTAL") 
        + "\n" + "***********************************************************************************************\n")
        for val in self.__investments[self.__year].items():
            display += "{a:<15s} {b:<15.2f} {c:<15.2f} {d:<20.2f} {e:<15.2f} {f:<15.2f}".format(a=val[0], b=val[1]["stocks"], c=val[1]["crypto"], d=val[1]["retirement_fund"], e=val[1]["realstate"], f=val[1]["total"]) + "\n" 
        display += "***********************************************************************************************\n"
        return display

        # an instance of budget class should maintain a dictionary with month name as the key and key value should maintain another dictionary. 
        # That inner dictionary should have income, expense and investment as the keys and key values should maintain another dictinary. This inner dictionary should have   
        # self.__year = year
        # self.__budget_dict = {self.__year: {"January": {"Income": {}, "Expenses": {}, "Investment": {}}, 
        #                                     "February": {"Income": {}, "Expenses": {}, "Investment": {}}, 
        #                                     "March": {"Income": {}, "Expenses": {}, "Investment": {}}, 
        #                                     "April": {"Income": {}, "Expenses": {}, "Investment": {}}, 
        #                                     "May": {"Income": {}, "Expenses": {}, "Investment": {}}, 
        #                                     "June": {"Income": {}, "Expenses": {}, "Investment": {}}, 
        #                                     "July": {"Income": {}, "Expenses": {}, "Investment": {}}, 
        #                                     "August": {"Income": {}, "Expenses": {}, "Investment": {}}, 
        #                                     "September": {"Income": {}, "Expenses": {}, "Investment": {}}, 
        #                                     "October": {"Income": {}, "Expenses": {}, "Investment": {}}, 
        #                                     "November": {"Income": {}, "Expenses": {}, "Investment": {}}, 
        #                                     "December": {"Income": {}, "Expenses": {}, "Investment": {}}}}
        # return None
    
    # def update_realstate(self, year, month, realstate):
    #     temp = self.investments[year][month]["realstate"] 
    #     self.investments[year][month]["realstate"] = realstate
    #     self.investments[year][month]["total"] += (realstate - temp)
    #     self.investments[year]["Total"]["realstate"] += (realstate - temp)
    #     self.investments[year]["Total"]["total"] += (realstate - temp)
    #     return "Realstate investment has been updated"


    # def money_in(self, month = None):
    #     if month == None:
    #         calculate total money that came in for that year by adding salary, bonus and HSA for all the months of that year
    #     else:
    #         calculate total money that came in for that month by adding salary, bonus and HSA for that month
   
    # def money_out(self, month = None):
    #     if month == None:
    #         calculate total money that went out for that year by adding bill, grocery, medical, travel and other for all the months of that year
    #     else:
    #         calculate total money that went out for that month by adding bill, grocery, medical, travel and other for that month

        

# a = Income(2021, "January", 1200, 1200)
# print(a.monthly_income())
# a.add_income(2021, "February", 2000, 1000)
# a.update_bonus(2021, "January", 1500)
# b = Expense(2021, "January", 3500, 2000, 1000, 500, 1000)
# b.add_expenses(2021, "December", 3000, 2000, 1100, 200, 600)
# print(b.monthly_expenses())
# c = Investment(2021, "February", 1000, 1000, 200, 500)
# c.add_investment(2021, "January", 2000, 10000, 1400, 50000)
# b.update_auto_expenses(2021, "March", 200)
# print(c.monthly_investment())
# print(a)
# print(b)
# print(c)
# c.update_crypto(2021, "May", 1600)
# print(c)
d = Budget(2022)
print(d)
d.update_realstate(2022, "June", 2000)
d.update_salary(2022, "May", 20000)
print(d)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-166-5e201a73fae2> in <module>
#     367 # print(c)
#     368 d = Budget(2022)
# --> 369 print(d)
#     370 d.update_realstate(2022, "June", 2000)
#     371 d.update_salary(2022, "May", 20000)
#
# <ipython-input-166-5e201a73fae2> in __str__(self)
#     291             + "\n {a:<15s} {b:<15s} {c:<15s} {d:<15s}".format(a="MONTH", b="SALARY", c="BONUS", d="TOTAL")
#     292             + "\n" + "************************************************************\n")
# --> 293         for val in self.__income[self.__year].items():
#     294             display += "{a:<15s} {b:<15.2f} {c:<15.2f} {d:<15.2f}".format(a=val[0], b=val[1]["salary"], c=val[1]["bonus"], d=val[1]["total"]) + "\n"
#     295         display += "************************************************************\n"
#
# ...
